# %% [markdown]
# # Testing Monopoly v1
#
# Testing the `Player` class.

# %%
from test import Test
from Monopoly import Player

# %%
Test.player_init()
# Out:
# Test passed: Object initiated as expected.

# %%
Test.player_set()
# Out:
# Test passed: Object was set as expected.

# %%
Test.player_assign()
# Out:
# Test passed: Object was assigned as expected.

# %%
Test.player_to_string()
# Out:
# Test passed: Player 1 is playing as the Duck with an account balance of £500

# %%
Test.player_representation()
# Out:
# Monopoly.Player("Player 1", "Duck", 500)

# %%
Test.player_equals()
# Out:
# Test passed.
