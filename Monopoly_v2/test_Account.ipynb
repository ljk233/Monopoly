# %% [markdown]
# # Testing Monopoly v2
#
# Testing the `Account` class.

# %%
from Monopoly.Account import Account

# %% [markdown]
# Declare and initialise an Account

# %%
a: Account = Account()

# %% [markdown]
# Test the **getters** and **setters.**

# %%
a.get_balance()
# Out:
# 500

# %%
a.set_balance(600)
a.get_balance()
# Out:
# 600

# %% [markdown]
# Test `credit()` method.

# %%
a.credit(150)  # expected, 750
a.get_balance()
# Out:
# 750

# %% [markdown]
# Test `debit()` method.

# %%
a.debit(250)  # expected, true
# Out:
# True

# %%
a.get_balance()  # expected, 500
# Out:
# 500

# %%
a.debit(600)  # expected, false
# Out:
# False

# %%
a.describe()
# Out:
# Account balance: £500
