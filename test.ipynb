# %% [markdown]
# # Testing Monopoly v1
#
# Testing the `Player` class.

# %%
from Monopoly import *

# %% [markdown]
# Declare and initialise one Account.

# %%
a1: Account = Account()

# %% [markdown]
# Test the **getters** and **setters.**

# %%
a1.get_balance()
# Out:
# 500

# %%
a1.set_balance(300)
a1.describe()
# Out:
# Account balance: £300

# %%
a1.credit(100)
a1.describe()
# Out:
# Account balance: £400

# %%
a1.debit(400)
# Out:
# True

# %%
a1.get_balance()
# Out:
# 0

# %%
a1.debit(400)
# Out:
# False

# %%
a1.get_balance()
# Out:
# 0

# %%
p1: Player = Player()
p2: Player = Player()

# %%
p1.assign_to("Player 1", "Dog")
p2.assign_to("Player 1", "Duck")

# %%
p1.account_credit(500)
p1.describe()
# Out:
# Player description
# ==================
# Name: Player 1
# Piece: Dog
# Account balance: £1000

# %%
p1.account_debit(500)
p1.describe()
# Out:
# Player description
# ==================
# Name: Player 1
# Piece: Dog
# Account balance: £500

# %%
p1.account_transfer(p2, 250)
# Out:
# True

# %%
p1.describe()
# Out:
# Player description
# ==================
# Name: Player 1
# Piece: Dog
# Account balance: £250

# %%
p2.describe()
# Out:
# Player description
# ==================
# Name: Player 1
# Piece: Duck
# Account balance: £750
